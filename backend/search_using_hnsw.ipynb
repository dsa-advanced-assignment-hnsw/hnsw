# %% [markdown]
# # **1. INSTALL LIBRARY & IMPORT LIBRARY**

# %% [markdown]
# *Install necessary library*

# %%
print(1)
# Out:
# 1

# %%
# !pip install git+https://github.com/openai/CLIP.git
# !pip install torch torchvision pillow
# !pip install numpy
# !pip install python-docx
# !pip install pymupdf
# !pip install beautifulsoup4 lxml
# !pip install hnswlib
# !pip install h5py

# %% [markdown]
# *Import library*

# %%
import torch
import clip
import os
import fitz
import docx
import hnswlib
import numpy as np
from bs4 import BeautifulSoup
from PIL import Image
import torch.nn.functional as F
import h5py

# %% [markdown]
# # **2. CLONE DATASETS FROM REPO GITHUB**
# *This repo is has some image and text to test this model*

# %%
Datasets = ["https://github.com/huynguyen6906/Data-for-HNSW-model.git"]
if os.path.isdir("/content/Datasets"):
  # !rm -rf "/content/Datasets/*"
else:
  # !mkdir Datasets

# %%
for Dataset in Datasets:
  # !cd Datasets/ && git clone $Dataset
# Out:
# Cloning into 'Data-for-HNSW-model'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 54 (delta 6), reused 50 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (54/54), 1.01 MiB | 19.48 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %% [markdown]
# # **3. CONVERT IMAGES TO VECTORS**

# %%
class convertToVector:
  def __init__(self):
    # Select device (use GPU if available)
    self.device = "cuda" if torch.cuda.is_available() else "cpu"
    # Load model CLIP
    self.model, self.preprocess = clip.load("ViT-B/32", device=self.device)
    self.Dataset_path = ""
    self.image_vectors = {}
    self.text_vectors = {}

  def loadDataset(self, Dataset_path):
    self.Dataset_path = Dataset_path

  def ConvertToVector(self):
    for dirpath, dirnames, filenames in os.walk(Dataset_path):
      for filename in filenames:
        file_path = os.path.join(dirpath, filename)
        text_content = ""

        if filename.lower().endswith(".jpeg"):
          image = self.preprocess(Image.open(file_path)).unsqueeze(0).to(self.device)
          vector = self.model.encode_image(image)
          vector = vector / vector.norm(dim=-1, keepdim=True)
          self.image_vectors[file_path] = vector.cpu()

        elif filename.endswith(".txt"):
            with open(file_path, "r", encoding="utf-8") as f:
                text_content = f.read()
            text_content = text_content.strip()

            # Tokenize and encode text
            text_tokens = clip.tokenize([text_content]).to(self.device)
            vector = self.model.encode_text(text_tokens)
            vector = vector / vector.norm(dim=-1, keepdim=True)  # normalize

            # Save vector
            self.text_vectors[file_path] = vector.cpu()

        elif filename.endswith(".pdf"):
            doc = fitz.open(file_path)
            for page in doc:
                text_content += page.get_text("text") + " "
            doc.close()
            text_content = text_content.strip()

            # Tokenize and encode text
            text_tokens = clip.tokenize([text_content]).to(self.device)
            vector = self.model.encode_text(text_tokens)
            vector = vector / vector.norm(dim=-1, keepdim=True)  # normalize

            # Save vector
            self.text_vectors[file_path] = vector.cpu()

        elif filename.endswith(".docx"):
            doc = docx.Document(file_path)
            for para in doc.paragraphs:
                text_content += para.text + " "
            text_content = text_content.strip()

            # Tokenize and encode text
            text_tokens = clip.tokenize([text_content]).to(self.device)
            vector = self.model.encode_text(text_tokens)
            vector = vector / vector.norm(dim=-1, keepdim=True)  # normalize

            # Save vector
            self.text_vectors[file_path] = vector.cpu()

        elif filename.endswith(".html") or filename.endswith(".htm"):
            with open(file_path, "r", encoding="utf-8") as f:
                html_content = f.read()
            soup = BeautifulSoup(html_content, "lxml")
            text_content = soup.get_text(separator=" ", strip=True)
            text_content = text_content.strip()

            # Tokenize and encode text
            text_tokens = clip.tokenize([text_content]).to(self.device)
            vector = self.model.encode_text(text_tokens)
            vector = vector / vector.norm(dim=-1, keepdim=True)  # normalize

            # Save vector
            self.text_vectors[file_path] = vector.cpu()
    print (len(self.image_vectors)," images was converted.")
    print (len(self.text_vectors)," text was converted.")

  def find_best_similar_image(self, text, option):
    best_similar_image = ""
    temp = -1
    if option:
      text_tokens = clip.tokenize([text.strip()]).to(self.device)
      vector_text = self.model.encode_text(text_tokens)
      vector_text = (vector_text / vector_text.norm(dim=-1, keepdim=True)).cpu()
      for file_path, vector in self.image_vectors.items():
        similarity_value = F.cosine_similarity(vector_text, vector, dim=1).item()
        if abs(similarity_value - 1) < abs(temp - 1):
          temp = similarity_value
          best_similar_image = file_path
    else:
      pass
    return best_similar_image

  def find_best_similar_text(self, text, option):
    best_similar_text = ""
    temp = -1
    if option:
      text_tokens = clip.tokenize([text.strip()]).to(self.device)
      vector_text = self.model.encode_text(text_tokens)
      vector_text = (vector_text / vector_text.norm(dim=-1, keepdim=True)).cpu()
      for file_path, vector in self.text_vectors.items():
        similarity_value = F.cosine_similarity(vector_text, vector, dim=1).item()
        if abs(similarity_value - 1) < abs(temp - 1):
          temp = similarity_value
          best_similar_text = file_path
    else:
      pass
    return best_similar_text

# %%
Dataset_path = "Datasets/"
convert = convertToVector();
convert.loadDataset(Dataset_path)
convert.ConvertToVector()
print(convert.find_best_similar_image("dog", 1))
print(convert.find_best_similar_text("BK", 1))
# Out:
# 100%|███████████████████████████████████████| 338M/338M [00:03<00:00, 98.4MiB/s]
# 23  images was converted.
# 11  text was converted.
# Datasets/Data-for-HNSW-model/image/dog1.jpeg
# Datasets/Data-for-HNSW-model/text/text4.txt

# %%
train_image_dataset = []
train_image_path = []
for path, vec in convert.image_vectors.items():
  train_image_dataset.append(vec.detach().numpy()[0])
  train_image_path.append(path)
train_image_dataset = np.array(train_image_dataset)

train_text_dataset = []
train_text_path = []
for path, vec in convert.text_vectors.items():
  train_text_dataset.append(vec.detach().numpy()[0])
  train_text_path.append(path)
train_text_dataset = np.array(train_text_dataset)

print(train_image_path)
print(train_text_path)
# Out:
# ['Datasets/Data-for-HNSW-model/image/bug3.jpeg', 'Datasets/Data-for-HNSW-model/image/cow3.jpeg', 'Datasets/Data-for-HNSW-model/image/dog1.jpeg', 'Datasets/Data-for-HNSW-model/image/cat1.jpeg', 'Datasets/Data-for-HNSW-model/image/mountain4.jpeg', 'Datasets/Data-for-HNSW-model/image/mountain2.jpeg', 'Datasets/Data-for-HNSW-model/image/cow4.jpeg', 'Datasets/Data-for-HNSW-model/image/cow1.jpeg', 'Datasets/Data-for-HNSW-model/image/mountain3.jpeg', 'Datasets/Data-for-HNSW-model/image/mountain1.jpeg', 'Datasets/Data-for-HNSW-model/image/human1.jpeg', 'Datasets/Data-for-HNSW-model/image/bug4.jpeg', 'Datasets/Data-for-HNSW-model/image/dog4.jpeg', 'Datasets/Data-for-HNSW-model/image/dog2.jpeg', 'Datasets/Data-for-HNSW-model/image/bug2.jpeg', 'Datasets/Data-for-HNSW-model/image/dog3.jpeg', 'Datasets/Data-for-HNSW-model/image/cat3.jpeg', 'Datasets/Data-for-HNSW-model/image/bug1.jpeg', 'Datasets/Data-for-HNSW-model/image/human3.jpeg', 'Datasets/Data-for-HNSW-model/image/human2.jpeg', 'Datasets/Data-for-HNSW-model/image/cat2.jpeg', 'Datasets/Data-for-HNSW-model/image/cat4.jpeg', 'Datasets/Data-for-HNSW-model/image/cow2.jpeg']
# ['Datasets/Data-for-HNSW-model/text/text1.docx', 'Datasets/Data-for-HNSW-model/text/text5.txt', 'Datasets/Data-for-HNSW-model/text/text7.txt', 'Datasets/Data-for-HNSW-model/text/text1.txt', 'Datasets/Data-for-HNSW-model/text/text2.txt', 'Datasets/Data-for-HNSW-model/text/text2.pdf', 'Datasets/Data-for-HNSW-model/text/text1.pdf', 'Datasets/Data-for-HNSW-model/text/text6.txt', 'Datasets/Data-for-HNSW-model/text/text3.txt', 'Datasets/Data-for-HNSW-model/text/text2.docx', 'Datasets/Data-for-HNSW-model/text/text4.txt']

# %% [markdown]
# *Another Convert class (convert something to vector and return as numpy.ndarray)*

# %%
class Convert:
  def __init__(self):
    # Select device (use GPU if available)
    self.device = "cuda" if torch.cuda.is_available() else "cpu"
    # Load model CLIP
    self.model, self.preprocess = clip.load("ViT-B/32", device=self.device)

  def convert_to_vector(self, file_path):
    filename = os.path.basename(file_path)
    text_content = ""
    vector = None

    if filename.lower().endswith(".jpeg"):
      image = self.preprocess(Image.open(file_path)).unsqueeze(0).to(self.device)
      vector = self.model.encode_image(image)
      vector = vector / vector.norm(dim=-1, keepdim=True)

    elif filename.endswith(".txt"):
      with open(file_path, "r", encoding="utf-8") as f:
          text_content = f.read()
      text_content = text_content.strip()

      # Tokenize and encode text
      text_tokens = clip.tokenize([text_content]).to(self.device)
      vector = self.model.encode_text(text_tokens)
      vector = vector / vector.norm(dim=-1, keepdim=True)  # normalize

    elif filename.endswith(".pdf"):
      doc = fitz.open(file_path)
      for page in doc:
          text_content += page.get_text("text") + " "
      doc.close()
      text_content = text_content.strip()

      # Tokenize and encode text
      text_tokens = clip.tokenize([text_content]).to(self.device)
      vector = self.model.encode_text(text_tokens)
      vector = vector / vector.norm(dim=-1, keepdim=True)  # normalize

    elif filename.endswith(".docx"):
      doc = docx.Document(file_path)
      for para in doc.paragraphs:
          text_content += para.text + " "
      text_content = text_content.strip()

      # Tokenize and encode text
      text_tokens = clip.tokenize([text_content]).to(self.device)
      vector = self.model.encode_text(text_tokens)
      vector = vector / vector.norm(dim=-1, keepdim=True)  # normalize

    elif filename.endswith(".html") or filename.endswith(".htm"):
      with open(file_path, "r", encoding="utf-8") as f:
          html_content = f.read()
      soup = BeautifulSoup(html_content, "lxml")
      text_content = soup.get_text(separator=" ", strip=True)
      text_content = text_content.strip()

      # Tokenize and encode text
      text_tokens = clip.tokenize([text_content]).to(self.device)
      vector = self.model.encode_text(text_tokens)
      vector = vector / vector.norm(dim=-1, keepdim=True)  # normalize

    return vector.cpu().detach().numpy()[0]

# %% [markdown]
# # **4. READ DATASETS**

# %%
with h5py.File("images_embeds.h5", "r") as f:
  texts = f["image_path"][:]
  embs = f["embeddings"][:]

# %% [markdown]
# # **5. HNSW IMPLEMENT**

# %% [markdown]
# *Construct HNSW*

# %%
dim = embs.shape[1]

index = hnswlib.Index(space='cosine', dim=dim)
index.init_index(max_elements = int(5e5), ef_construction = 400, M = 200)
index.set_ef(200)

index.add_items(embs)

# %%
def request_text_to_vector(text):
  device = "cuda" if torch.cuda.is_available() else "cpu"
  model, preprocess = clip.load("ViT-B/32", device=device)
  text_tokens = clip.tokenize([text.strip()]).to(device)
  vector_text = model.encode_text(text_tokens)
  vector_text = (vector_text / vector_text.norm(dim=-1, keepdim=True)).cpu()
  return vector_text.detach().numpy().astype(np.float32)

# %%
query = request_text_to_vector("beach")
# Out:
#  32%|████████████▊                           | 108M/338M [04:25<04:21, 920kiB/s]

# %% [markdown]
# # **6. SEARCH QUERIES**

# %%
# @title
indices, distances = index.knn_query(embs, k=5)
for idx in indices[0]:
  print(texts[idx])
# Out:
# b'./images/34894.jpg'
# b'./images/689570.jpg'
# b'./images/401534.jpg'
# b'./images/13890.jpg'
# b'./images/753786.jpg'
# b'./images/481912.jpg'
# b'./images/249948.jpg'
# b'./images/657890.jpg'
# b'./images/899976.jpg'
# b'./images/467526.jpg'
# b'./images/694896.jpg'
# b'./images/184986.jpg'
# b'./images/560966.jpg'
# b'./images/756796.jpg'
# b'./images/887326.jpg'
# b'./images/693890.jpg'
# b'./images/933612.jpg'
# b'./images/105576.jpg'
# b'./images/381220.jpg'
# b'./images/682702.jpg'
# b'./images/127654.jpg'
# b'./images/396298.jpg'
# b'./images/618106.jpg'
# b'./images/67160.jpg'
# b'./images/779006.jpg'
# b'./images/231576.jpg'
# b'./images/563848.jpg'
# b'./images/705678.jpg'
# b'./images/520568.jpg'
# b'./images/340980.jpg'
# b'./images/46028.jpg'
# b'./images/922024.jpg'
# b'./images/300834.jpg'
# b'./images/484832.jpg'
# b'./images/537266.jpg'
# b'./images/150926.jpg'
# b'./images/600846.jpg'
# b'./images/253200.jpg'
# b'./images/52154.jpg'
# b'./images/869372.jpg'
# b'./images/850144.jpg'
# b'./images/164634.jpg'
# b'./images/573022.jpg'
# b'./images/893582.jpg'
# b'./images/580520.jpg'
# b'./images/810264.jpg'
# b'./images/557290.jpg'
# b'./images/464218.jpg'
# b'./images/912460.jpg'
# b'./images/731152.jpg'
# b'./images/651166.jpg'
# b'./images/218594.jpg'
# b'./images/285576.jpg'
# b'./images/360326.jpg'
# b'./images/20764.jpg'
# b'./images/587142.jpg'
# b'./images/425984.jpg'
# b'./images/473644.jpg'
# b'./images/97346.jpg'
# b'./images/252622.jpg'
# b'./images/816244.jpg'
# b'./images/444892.jpg'
# b'./images/139264.jpg'
# b'./images/824172.jpg'
# b'./images/18168.jpg'
# b'./images/52260.jpg'
# b'./images/567826.jpg'
# b'./images/778258.jpg'
# b'./images/440352.jpg'
# b'./images/307762.jpg'
# b'./images/582728.jpg'
# b'./images/772284.jpg'
# b'./images/122328.jpg'
# b'./images/509874.jpg'
# b'./images/421556.jpg'
# b'./images/429464.jpg'
# b'./images/221208.jpg'
# b'./images/703466.jpg'
# b'./images/734436.jpg'
# b'./images/795054.jpg'
# b'./images/665712.jpg'
# b'./images/544360.jpg'
# b'./images/887016.jpg'
# b'./images/469048.jpg'
# b'./images/953338.jpg'
# b'./images/312078.jpg'
# b'./images/500750.jpg'
# b'./images/679276.jpg'
# b'./images/463268.jpg'
# b'./images/252556.jpg'
# b'./images/970156.jpg'
# b'./images/795942.jpg'
# b'./images/212140.jpg'
# b'./images/791682.jpg'
# b'./images/263070.jpg'
# b'./images/892332.jpg'
# b'./images/478256.jpg'
# b'./images/522588.jpg'
# b'./images/821800.jpg'
# b'./images/471460.jpg'
# b'./images/46922.jpg'
# b'./images/343076.jpg'
# b'./images/212428.jpg'
# b'./images/774234.jpg'
# b'./images/174172.jpg'
# b'./images/986164.jpg'
# b'./images/465176.jpg'
# b'./images/472754.jpg'
# b'./images/14700.jpg'
# b'./images/510884.jpg'
# b'./images/20630.jpg'
# b'./images/964214.jpg'
# b'./images/160984.jpg'
# b'./images/899526.jpg'
# b'./images/901702.jpg'
# b'./images/516882.jpg'
# b'./images/790650.jpg'
# b'./images/381452.jpg'
# b'./images/849742.jpg'
# b'./images/426940.jpg'
# b'./images/613224.jpg'
# b'./images/684494.jpg'
# b'./images/222218.jpg'
# b'./images/787342.jpg'
# b'./images/570590.jpg'
# b'./images/329098.jpg'
# b'./images/757974.jpg'
# b'./images/537476.jpg'
# b'./images/363714.jpg'
# b'./images/262600.jpg'
# b'./images/817684.jpg'
# b'./images/116296.jpg'
# b'./images/994398.jpg'
# b'./images/219644.jpg'
# b'./images/653364.jpg'
# b'./images/915920.jpg'
# b'./images/13382.jpg'
# b'./images/502122.jpg'
# b'./images/474730.jpg'
# b'./images/939640.jpg'
# b'./images/857888.jpg'
# b'./images/496858.jpg'
# b'./images/749322.jpg'
# b'./images/196418.jpg'
# b'./images/48234.jpg'
# b'./images/453836.jpg'
# b'./images/725398.jpg'
# b'./images/494836.jpg'
# b'./images/742456.jpg'
# b'./images/862332.jpg'
# b'./images/645554.jpg'
# b'./images/537456.jpg'
# b'./images/793292.jpg'
# b'./images/57098.jpg'
# b'./images/506626.jpg'
# b'./images/558670.jpg'
# b'./images/562956.jpg'
# b'./images/513558.jpg'
# b'./images/759102.jpg'
# b'./images/702942.jpg'
# b'./images/895226.jpg'
# b'./images/845432.jpg'
# b'./images/960812.jpg'
# b'./images/720236.jpg'
# b'./images/782494.jpg'
# b'./images/256672.jpg'
# b'./images/791114.jpg'
# b'./images/913658.jpg'
# b'./images/515758.jpg'
# b'./images/271188.jpg'
# b'./images/616780.jpg'
# b'./images/69868.jpg'
# b'./images/421030.jpg'
# b'./images/144986.jpg'
# b'./images/34154.jpg'
# b'./images/219738.jpg'
# b'./images/751782.jpg'
# b'./images/773922.jpg'
# b'./images/228222.jpg'
# b'./images/293528.jpg'
# b'./images/580198.jpg'
# b'./images/504376.jpg'
# b'./images/232064.jpg'
# b'./images/216248.jpg'
# b'./images/116462.jpg'
# b'./images/400426.jpg'
# b'./images/274526.jpg'
# b'./images/165904.jpg'
# b'./images/125204.jpg'
# b'./images/843964.jpg'
# b'./images/403406.jpg'
# b'./images/920310.jpg'
# b'./images/577110.jpg'
# b'./images/594462.jpg'
# b'./images/382276.jpg'
# b'./images/100038.jpg'
# b'./images/909098.jpg'
# b'./images/372740.jpg'
# b'./images/435582.jpg'
# b'./images/207160.jpg'
# b'./images/258098.jpg'
# b'./images/541452.jpg'
# b'./images/37228.jpg'
# b'./images/140576.jpg'
# b'./images/715806.jpg'
# b'./images/690538.jpg'
# b'./images/679324.jpg'
# b'./images/549116.jpg'
# b'./images/681254.jpg'
# b'./images/737328.jpg'
# b'./images/111268.jpg'
# b'./images/454050.jpg'
# b'./images/432534.jpg'
# b'./images/644322.jpg'
# b'./images/631480.jpg'
# b'./images/427396.jpg'
# b'./images/583164.jpg'
# b'./images/792502.jpg'
# b'./images/602460.jpg'
# b'./images/956904.jpg'
# b'./images/825020.jpg'
# b'./images/91092.jpg'
# b'./images/913934.jpg'
# b'./images/18108.jpg'
# b'./images/418584.jpg'
# b'./images/561860.jpg'
# b'./images/299728.jpg'
# b'./images/178968.jpg'
# b'./images/417488.jpg'
# b'./images/709844.jpg'
# b'./images/511980.jpg'
# b'./images/628426.jpg'
# b'./images/360468.jpg'
# b'./images/324662.jpg'
# b'./images/781222.jpg'
# b'./images/306552.jpg'
# b'./images/320002.jpg'
# b'./images/81536.jpg'
# b'./images/907104.jpg'
# b'./images/184538.jpg'
# b'./images/545944.jpg'
# b'./images/419502.jpg'
# b'./images/589826.jpg'
# b'./images/321720.jpg'
# b'./images/528666.jpg'
# b'./images/709038.jpg'
# b'./images/442302.jpg'
# b'./images/129730.jpg'
# b'./images/300966.jpg'
# b'./images/61676.jpg'
# b'./images/808898.jpg'
# b'./images/444086.jpg'
# b'./images/706074.jpg'
# b'./images/900012.jpg'
# b'./images/859622.jpg'
# b'./images/902834.jpg'
# b'./images/962970.jpg'
# b'./images/152082.jpg'
# b'./images/104268.jpg'
# b'./images/430528.jpg'
# b'./images/938000.jpg'
# b'./images/482274.jpg'
# b'./images/109062.jpg'
# b'./images/993126.jpg'
# b'./images/727470.jpg'
# b'./images/48444.jpg'
# b'./images/417024.jpg'
# b'./images/594576.jpg'
# b'./images/806022.jpg'
# b'./images/481192.jpg'
# b'./images/602350.jpg'
# b'./images/734668.jpg'
# b'./images/361442.jpg'
# b'./images/988860.jpg'
# b'./images/730118.jpg'
# b'./images/134290.jpg'
# b'./images/558530.jpg'
# b'./images/946404.jpg'
# b'./images/461100.jpg'
# b'./images/636874.jpg'
# b'./images/199908.jpg'
# b'./images/718784.jpg'
# b'./images/670040.jpg'
# b'./images/642930.jpg'
# b'./images/684962.jpg'
# b'./images/726146.jpg'
# b'./images/938852.jpg'
# b'./images/43256.jpg'
# b'./images/222860.jpg'
# b'./images/374034.jpg'
# b'./images/289276.jpg'
# b'./images/57162.jpg'
# b'./images/395758.jpg'
# b'./images/711576.jpg'
# b'./images/834122.jpg'
# b'./images/907920.jpg'
# b'./images/946668.jpg'
# b'./images/743026.jpg'
# b'./images/553958.jpg'
# b'./images/209868.jpg'
# b'./images/900250.jpg'
# b'./images/798378.jpg'
# b'./images/629618.jpg'
# b'./images/658100.jpg'
# b'./images/142608.jpg'
# b'./images/421308.jpg'
# b'./images/218558.jpg'
# b'./images/219010.jpg'
# b'./images/599916.jpg'
# b'./images/605012.jpg'
# b'./images/544616.jpg'
# b'./images/962210.jpg'
# b'./images/219942.jpg'
# b'./images/438708.jpg'
# b'./images/104610.jpg'
# b'./images/506672.jpg'
# b'./images/220504.jpg'
# b'./images/25712.jpg'
# b'./images/307274.jpg'
# b'./images/673330.jpg'
# b'./images/611792.jpg'
# b'./images/131360.jpg'
# b'./images/346506.jpg'
# b'./images/654590.jpg'
# b'./images/493106.jpg'
# b'./images/499280.jpg'
# b'./images/629130.jpg'
# b'./images/701046.jpg'
# b'./images/609558.jpg'
# b'./images/118110.jpg'
# b'./images/714124.jpg'
# b'./images/870336.jpg'
# b'./images/353510.jpg'
# b'./images/350052.jpg'
# b'./images/605346.jpg'
# b'./images/313792.jpg'
# b'./images/362658.jpg'
# b'./images/468046.jpg'
# b'./images/912266.jpg'
# b'./images/124184.jpg'
# b'./images/962924.jpg'
# b'./images/656140.jpg'
# b'./images/124892.jpg'
# b'./images/840038.jpg'
# b'./images/280070.jpg'
# b'./images/540340.jpg'
# b'./images/695932.jpg'
# b'./images/228140.jpg'
# b'./images/386802.jpg'
# b'./images/692860.jpg'
# b'./images/470622.jpg'
# b'./images/842218.jpg'
# b'./images/593500.jpg'
# b'./images/113540.jpg'
# b'./images/354904.jpg'
# b'./images/801842.jpg'
# b'./images/460026.jpg'
# b'./images/922808.jpg'
# b'./images/934014.jpg'
# b'./images/399824.jpg'
# b'./images/873976.jpg'
# b'./images/588616.jpg'
# b'./images/440862.jpg'
# b'./images/31010.jpg'
# b'./images/462122.jpg'
# b'./images/723552.jpg'
# b'./images/393774.jpg'
# b'./images/687250.jpg'
# b'./images/327142.jpg'
# b'./images/124742.jpg'
# b'./images/800320.jpg'
# b'./images/403792.jpg'
# b'./images/359006.jpg'
# b'./images/994836.jpg'
# b'./images/441186.jpg'
# b'./images/874172.jpg'
# b'./images/521074.jpg'
# b'./images/70220.jpg'
# b'./images/81792.jpg'
# b'./images/918432.jpg'
# b'./images/260284.jpg'
# b'./images/534238.jpg'
# b'./images/525696.jpg'
# b'./images/467046.jpg'
# b'./images/778844.jpg'
# b'./images/976968.jpg'
# b'./images/668514.jpg'
# b'./images/123666.jpg'
# b'./images/147678.jpg'
# b'./images/391262.jpg'
# b'./images/483600.jpg'
# b'./images/738140.jpg'
# b'./images/887412.jpg'
# b'./images/222460.jpg'
# b'./images/789634.jpg'
# b'./images/220024.jpg'
# b'./images/899626.jpg'
# b'./images/338290.jpg'
# b'./images/44092.jpg'
# b'./images/230780.jpg'
# b'./images/611134.jpg'
# b'./images/753622.jpg'
# b'./images/996236.jpg'
# b'./images/748948.jpg'
# b'./images/868382.jpg'
# b'./images/682930.jpg'
# b'./images/517974.jpg'
# b'./images/773570.jpg'
# b'./images/257098.jpg'
# b'./images/773698.jpg'
# b'./images/202066.jpg'
# b'./images/958178.jpg'
# b'./images/13718.jpg'
# b'./images/245306.jpg'
# b'./images/425028.jpg'
# b'./images/616174.jpg'
# b'./images/843822.jpg'
# b'./images/292482.jpg'
# b'./images/210474.jpg'
# b'./images/229524.jpg'
# b'./images/903984.jpg'
# b'./images/573860.jpg'
# b'./images/162954.jpg'
# b'./images/203182.jpg'
# b'./images/802548.jpg'
# b'./images/83786.jpg'
# b'./images/319036.jpg'
# b'./images/74952.jpg'
# b'./images/738280.jpg'
# b'./images/770086.jpg'
# b'./images/594412.jpg'
# b'./images/72050.jpg'
# b'./images/834640.jpg'
# b'./images/557426.jpg'
# b'./images/497818.jpg'
# b'./images/189884.jpg'
# b'./images/631318.jpg'
# b'./images/912532.jpg'
# b'./images/755880.jpg'
# b'./images/939718.jpg'
# b'./images/298728.jpg'
# b'./images/639904.jpg'
# b'./images/395890.jpg'
# b'./images/416822.jpg'
# b'./images/829560.jpg'
# b'./images/404770.jpg'
# b'./images/316396.jpg'
# b'./images/386340.jpg'
# b'./images/372826.jpg'
# b'./images/485380.jpg'
# b'./images/971464.jpg'
# b'./images/143422.jpg'
# b'./images/153928.jpg'
# b'./images/482834.jpg'
# b'./images/628780.jpg'
# b'./images/138348.jpg'
# b'./images/945086.jpg'
# b'./images/6580.jpg'
# b'./images/89250.jpg'
# b'./images/46786.jpg'
# b'./images/796934.jpg'
# b'./images/644346.jpg'
# b'./images/87896.jpg'
# b'./images/858814.jpg'
# b'./images/76330.jpg'
# b'./images/954826.jpg'
# b'./images/166378.jpg'
# b'./images/757498.jpg'
# b'./images/367632.jpg'
# b'./images/227366.jpg'
# b'./images/931934.jpg'
# b'./images/585272.jpg'
# b'./images/370924.jpg'
# b'./images/681198.jpg'
# b'./images/267090.jpg'
# b'./images/693694.jpg'
# b'./images/610740.jpg'
# b'./images/836530.jpg'
# b'./images/600842.jpg'
# b'./images/481694.jpg'
# b'./images/559014.jpg'
# b'./images/96762.jpg'
# b'./images/937748.jpg'
# b'./images/436796.jpg'
# b'./images/498642.jpg'
# b'./images/807124.jpg'
# b'./images/258064.jpg'
# b'./images/292504.jpg'
# b'./images/743806.jpg'
# b'./images/729206.jpg'
# b'./images/379664.jpg'
# b'./images/461924.jpg'
# b'./images/869278.jpg'
# b'./images/648388.jpg'
# b'./images/683620.jpg'
# b'./images/839516.jpg'
# b'./images/938150.jpg'
# b'./images/188704.jpg'
# b'./images/381822.jpg'
# b'./images/174520.jpg'
# b'./images/333230.jpg'
# b'./images/764726.jpg'
# b'./images/404612.jpg'
# b'./images/791330.jpg'
# b'./images/738002.jpg'
# b'./images/697516.jpg'
# b'./images/328480.jpg'
# b'./images/758148.jpg'
# b'./images/845492.jpg'
# b'./images/626304.jpg'
# b'./images/134730.jpg'
# b'./images/949094.jpg'
# b'./images/21086.jpg'
# b'./images/703070.jpg'
# b'./images/3346.jpg'
# b'./images/394582.jpg'
# b'./images/65232.jpg'
# b'./images/38078.jpg'
# b'./images/178222.jpg'
# b'./images/893050.jpg'
# b'./images/329986.jpg'
# b'./images/659786.jpg'
# b'./images/334808.jpg'
# b'./images/473308.jpg'
# b'./images/698198.jpg'
# b'./images/424188.jpg'
# b'./images/476484.jpg'
# b'./images/533796.jpg'
# b'./images/903678.jpg'
# b'./images/876574.jpg'
# b'./images/559710.jpg'
# b'./images/167290.jpg'
# b'./images/884682.jpg'
# b'./images/221722.jpg'
# b'./images/73280.jpg'
# b'./images/34072.jpg'
# b'./images/864392.jpg'
# b'./images/320550.jpg'
# b'./images/870322.jpg'
# b'./images/130382.jpg'
# b'./images/145774.jpg'
# b'./images/455506.jpg'
# b'./images/343596.jpg'
# b'./images/890712.jpg'
# b'./images/250564.jpg'
# b'./images/111700.jpg'
# b'./images/205858.jpg'
# b'./images/794408.jpg'
# b'./images/192578.jpg'
# b'./images/741472.jpg'
# b'./images/973654.jpg'
# b'./images/364362.jpg'
# b'./images/342052.jpg'
# b'./images/157586.jpg'
# b'./images/398380.jpg'
# b'./images/87390.jpg'
# b'./images/490696.jpg'
# b'./images/19596.jpg'
# b'./images/882340.jpg'
# b'./images/664132.jpg'
# b'./images/174866.jpg'
# b'./images/619840.jpg'
# b'./images/59736.jpg'
# b'./images/105408.jpg'
# b'./images/748056.jpg'
# b'./images/840400.jpg'
# b'./images/691004.jpg'
# b'./images/808616.jpg'
# b'./images/257776.jpg'
# b'./images/447358.jpg'
# b'./images/176402.jpg'
# b'./images/698262.jpg'
# b'./images/910830.jpg'
# b'./images/629166.jpg'
# b'./images/832470.jpg'
# b'./images/669188.jpg'
# b'./images/573514.jpg'
# b'./images/456890.jpg'
# b'./images/69858.jpg'
# b'./images/511074.jpg'
# b'./images/921266.jpg'
# b'./images/967368.jpg'
# b'./images/163038.jpg'
# b'./images/822936.jpg'
# b'./images/381316.jpg'
# b'./images/610422.jpg'
# b'./images/424864.jpg'
# b'./images/768236.jpg'
# b'./images/752720.jpg'
# b'./images/402516.jpg'
# b'./images/969226.jpg'
# b'./images/522650.jpg'
# b'./images/173748.jpg'
# b'./images/405796.jpg'
# b'./images/871340.jpg'
# b'./images/153504.jpg'
# b'./images/596958.jpg'
# b'./images/702528.jpg'
# b'./images/382994.jpg'
# b'./images/920518.jpg'
# b'./images/906210.jpg'
# b'./images/195606.jpg'
# b'./images/795848.jpg'
# b'./images/188188.jpg'
# b'./images/229506.jpg'
# b'./images/605048.jpg'
# b'./images/786428.jpg'
# b'./images/125972.jpg'
# b'./images/447524.jpg'
# b'./images/598554.jpg'
# b'./images/685444.jpg'
# b'./images/831138.jpg'
# b'./images/717606.jpg'
# b'./images/431274.jpg'
# b'./images/280696.jpg'
# b'./images/302598.jpg'
# b'./images/431088.jpg'
# b'./images/564646.jpg'
# b'./images/181808.jpg'
# b'./images/756404.jpg'
# b'./images/97328.jpg'
# b'./images/285358.jpg'
# b'./images/133362.jpg'
# b'./images/498834.jpg'
# b'./images/613950.jpg'
# b'./images/87462.jpg'
# b'./images/17118.jpg'
# b'./images/699080.jpg'
# b'./images/69782.jpg'
# b'./images/647162.jpg'
# b'./images/88876.jpg'
# b'./images/256832.jpg'
# b'./images/255598.jpg'
# b'./images/338010.jpg'
# b'./images/451146.jpg'
# b'./images/735710.jpg'
# b'./images/652022.jpg'
# b'./images/19952.jpg'
# b'./images/602724.jpg'
# b'./images/29114.jpg'
# b'./images/717228.jpg'
# b'./images/519262.jpg'
# b'./images/155596.jpg'
# b'./images/196320.jpg'
# b'./images/901676.jpg'
# b'./images/575848.jpg'
# b'./images/24494.jpg'
# b'./images/758624.jpg'
# b'./images/216612.jpg'
# b'./images/284950.jpg'
# b'./images/825956.jpg'
# b'./images/810516.jpg'
# b'./images/405250.jpg'
# b'./images/577974.jpg'
# b'./images/399802.jpg'
# b'./images/470206.jpg'
# b'./images/487472.jpg'
# b'./images/175142.jpg'
# b'./images/288864.jpg'
# b'./images/415750.jpg'
# b'./images/312974.jpg'
# b'./images/398548.jpg'
# b'./images/629732.jpg'
# b'./images/137350.jpg'
# b'./images/191170.jpg'
# b'./images/497324.jpg'
# b'./images/404860.jpg'
# b'./images/982464.jpg'
# b'./images/954608.jpg'
# b'./images/152122.jpg'
# b'./images/274204.jpg'
# b'./images/461882.jpg'
# b'./images/457168.jpg'
# b'./images/925204.jpg'
# b'./images/433826.jpg'
# b'./images/799972.jpg'
# b'./images/82184.jpg'
# b'./images/516560.jpg'
# b'./images/152148.jpg'
# b'./images/278050.jpg'
# b'./images/4508.jpg'
# b'./images/6512.jpg'
# b'./images/48506.jpg'
# b'./images/943934.jpg'
# b'./images/289762.jpg'
# b'./images/58668.jpg'
# b'./images/368126.jpg'
# b'./images/969044.jpg'
# b'./images/660282.jpg'
# b'./images/810680.jpg'
# b'./images/483988.jpg'
# b'./images/419166.jpg'
# b'./images/263926.jpg'
# b'./images/852932.jpg'
# b'./images/459664.jpg'
# b'./images/716634.jpg'
# b'./images/646588.jpg'
# b'./images/780136.jpg'
# b'./images/253984.jpg'
# b'./images/731050.jpg'
# b'./images/467226.jpg'
# b'./images/612336.jpg'
# b'./images/190590.jpg'
# b'./images/928352.jpg'
# b'./images/232590.jpg'
# b'./images/726566.jpg'
# b'./images/664172.jpg'
# b'./images/280102.jpg'
# b'./images/192936.jpg'
# b'./images/618746.jpg'
# b'./images/653710.jpg'
# b'./images/190892.jpg'
# b'./images/118916.jpg'
# b'./images/31034.jpg'
# b'./images/282692.jpg'
# b'./images/260424.jpg'
# b'./images/738730.jpg'
# b'./images/816790.jpg'
# b'./images/906568.jpg'
# b'./images/424468.jpg'
# b'./images/575012.jpg'
# b'./images/340232.jpg'
# b'./images/762142.jpg'
# b'./images/170070.jpg'
# b'./images/910188.jpg'
# b'./images/864316.jpg'
# b'./images/417124.jpg'
# b'./images/532550.jpg'
# b'./images/681448.jpg'
# b'./images/886340.jpg'
# b'./images/340494.jpg'
# b'./images/450480.jpg'
# b'./images/757132.jpg'
# b'./images/784398.jpg'
# b'./images/339830.jpg'
# b'./images/52390.jpg'
# b'./images/698012.jpg'
# b'./images/869476.jpg'
# b'./images/607400.jpg'
# b'./images/507650.jpg'
# b'./images/391848.jpg'
# b'./images/782100.jpg'
# b'./images/482400.jpg'
# b'./images/678842.jpg'
# b'./images/453104.jpg'
# b'./images/56500.jpg'
# b'./images/170442.jpg'
# b'./images/798154.jpg'
# b'./images/520618.jpg'
# b'./images/608172.jpg'
# b'./images/532566.jpg'
# b'./images/376950.jpg'
# b'./images/351684.jpg'
# b'./images/394358.jpg'
# b'./images/435948.jpg'
# b'./images/132522.jpg'
# b'./images/843616.jpg'
# b'./images/830198.jpg'
# b'./images/877384.jpg'
# b'./images/521964.jpg'
# b'./images/292590.jpg'
# b'./images/388330.jpg'
# b'./images/551722.jpg'
# b'./images/825640.jpg'
# b'./images/315132.jpg'
# b'./images/53658.jpg'
# b'./images/215592.jpg'
# b'./images/552970.jpg'
# b'./images/643104.jpg'
# b'./images/409002.jpg'
# b'./images/746530.jpg'
# b'./images/577564.jpg'
# b'./images/779304.jpg'
# b'./images/647778.jpg'
# b'./images/466122.jpg'
# b'./images/356908.jpg'
# b'./images/826786.jpg'
# b'./images/215328.jpg'
# b'./images/169804.jpg'
# b'./images/668980.jpg'
# b'./images/596864.jpg'
# b'./images/306940.jpg'
# b'./images/574466.jpg'
# b'./images/984414.jpg'
# b'./images/764416.jpg'
# b'./images/241674.jpg'
# b'./images/953570.jpg'
# b'./images/719648.jpg'
# b'./images/361344.jpg'
# b'./images/372716.jpg'
# b'./images/776630.jpg'
# b'./images/262632.jpg'
# b'./images/337364.jpg'
# b'./images/954404.jpg'
# b'./images/264644.jpg'
# b'./images/51198.jpg'
# b'./images/885348.jpg'
# b'./images/938164.jpg'
# b'./images/822362.jpg'
# b'./images/365140.jpg'
# b'./images/73318.jpg'
# b'./images/253944.jpg'
# b'./images/455354.jpg'
# b'./images/640724.jpg'
# b'./images/296180.jpg'
# b'./images/140888.jpg'
# b'./images/560498.jpg'
# b'./images/636210.jpg'
# b'./images/270114.jpg'
# b'./images/258368.jpg'
# b'./images/930116.jpg'
# b'./images/888274.jpg'
# b'./images/302368.jpg'
# b'./images/625414.jpg'
# b'./images/857756.jpg'
# b'./images/559580.jpg'
# b'./images/97590.jpg'
# b'./images/477514.jpg'
# b'./images/984.jpg'
# b'./images/730386.jpg'
# b'./images/871410.jpg'
# b'./images/775254.jpg'
# b'./images/883480.jpg'
# b'./images/18084.jpg'
# b'./images/462388.jpg'
# b'./images/281156.jpg'
# b'./images/764290.jpg'
# b'./images/73680.jpg'
# b'./images/405844.jpg'
# b'./images/284732.jpg'
# b'./images/334326.jpg'
# b'./images/502174.jpg'
# b'./images/891812.jpg'
# b'./images/778632.jpg'
# b'./images/655508.jpg'
# b'./images/234736.jpg'
# b'./images/380270.jpg'
# b'./images/459928.jpg'
# b'./images/785804.jpg'
# b'./images/392722.jpg'
# b'./images/201764.jpg'
# b'./images/627774.jpg'
# b'./images/499182.jpg'
# b'./images/23366.jpg'
# b'./images/421228.jpg'
# b'./images/606830.jpg'
# b'./images/444914.jpg'
# b'./images/380892.jpg'
# b'./images/672654.jpg'
# b'./images/545942.jpg'
# b'./images/560340.jpg'
# b'./images/219970.jpg'
# b'./images/698942.jpg'
# b'./images/694282.jpg'
# b'./images/104172.jpg'
# b'./images/64010.jpg'
# b'./images/971070.jpg'
# b'./images/4562.jpg'
# b'./images/563118.jpg'
# b'./images/407952.jpg'
# b'./images/34184.jpg'
# b'./images/24766.jpg'
# b'./images/881674.jpg'
# b'./images/199474.jpg'
# b'./images/643794.jpg'
# b'./images/343942.jpg'
# b'./images/47802.jpg'
# b'./images/973684.jpg'
# b'./images/286580.jpg'
# b'./images/959480.jpg'
# b'./images/462630.jpg'
# b'./images/173264.jpg'
# b'./images/73302.jpg'
# b'./images/455260.jpg'
# b'./images/324350.jpg'
# b'./images/340268.jpg'
# b'./images/374930.jpg'
# b'./images/167312.jpg'
# b'./images/752018.jpg'
# b'./images/89824.jpg'
# b'./images/60776.jpg'
# b'./images/745086.jpg'
# b'./images/878266.jpg'
# b'./images/315898.jpg'
# b'./images/33864.jpg'
# b'./images/837930.jpg'
# b'./images/994508.jpg'
# b'./images/735740.jpg'
# b'./images/79056.jpg'
# b'./images/61228.jpg'
# b'./images/318292.jpg'
# b'./images/989948.jpg'
# b'./images/796630.jpg'
# b'./images/107546.jpg'
# b'./images/9238.jpg'
# b'./images/181864.jpg'
# b'./images/557922.jpg'
# b'./images/413190.jpg'
# b'./images/149290.jpg'
# b'./images/154098.jpg'
# b'./images/719176.jpg'
# b'./images/983354.jpg'
# b'./images/144336.jpg'
# b'./images/320222.jpg'
# b'./images/875856.jpg'
# b'./images/67860.jpg'
# b'./images/477108.jpg'
# b'./images/995802.jpg'
# b'./images/176688.jpg'
# b'./images/206660.jpg'
# b'./images/832940.jpg'
# b'./images/121002.jpg'
# b'./images/541252.jpg'
# b'./images/251834.jpg'
# b'./images/798360.jpg'
# b'./images/325508.jpg'
# b'./images/26414.jpg'
# b'./images/506558.jpg'
# b'./images/826782.jpg'
# b'./images/229196.jpg'
# b'./images/842482.jpg'
# b'./images/614666.jpg'
# b'./images/503220.jpg'
# b'./images/242356.jpg'
# b'./images/823658.jpg'
# b'./images/270282.jpg'
# b'./images/273762.jpg'
# b'./images/570482.jpg'
# b'./images/44754.jpg'
# b'./images/864454.jpg'
# b'./images/300946.jpg'
# b'./images/602312.jpg'
# b'./images/545594.jpg'
# b'./images/76204.jpg'
# b'./images/461268.jpg'
# b'./images/156356.jpg'
# b'./images/4016.jpg'
# b'./images/580604.jpg'
# b'./images/419792.jpg'
# b'./images/535418.jpg'
# b'./images/239882.jpg'
# b'./images/434818.jpg'
# b'./images/247536.jpg'
# b'./images/914572.jpg'
# b'./images/988174.jpg'
# b'./images/584666.jpg'
# b'./images/930070.jpg'
# b'./images/256744.jpg'
# b'./images/406098.jpg'
# b'./images/294140.jpg'
# b'./images/522064.jpg'
# b'./images/661536.jpg'
# b'./images/632888.jpg'
# b'./images/54078.jpg'
# b'./images/181816.jpg'
# b'./images/212878.jpg'
# b'./images/262514.jpg'
# b'./images/504644.jpg'
# b'./images/90940.jpg'
# b'./images/761738.jpg'
# b'./images/125858.jpg'
# b'./images/945750.jpg'
# b'./images/825694.jpg'
# b'./images/51786.jpg'
# b'./images/369184.jpg'
# b'./images/236426.jpg'
# b'./images/575152.jpg'
# b'./images/864910.jpg'
# b'./images/11030.jpg'
# b'./images/412652.jpg'
# b'./images/953772.jpg'
# b'./images/582300.jpg'
# b'./images/383344.jpg'
# b'./images/69840.jpg'
# b'./images/871850.jpg'
# b'./images/606592.jpg'
# b'./images/748488.jpg'
# b'./images/392624.jpg'
# b'./images/12448.jpg'
# b'./images/994208.jpg'
# b'./images/960458.jpg'
# b'./images/659992.jpg'
# b'./images/315152.jpg'
# b'./images/153326.jpg'
# b'./images/989844.jpg'
# b'./images/912616.jpg'
# b'./images/988580.jpg'
# b'./images/61088.jpg'
# b'./images/830792.jpg'
# b'./images/995522.jpg'
# b'./images/960080.jpg'
# b'./images/240046.jpg'
# b'./images/838076.jpg'
# b'./images/593866.jpg'
# b'./images/891638.jpg'
# b'./images/901680.jpg'
# b'./images/251974.jpg'
# b'./images/396014.jpg'
# b'./images/335472.jpg'
# b'./images/624840.jpg'

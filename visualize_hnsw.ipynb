# %% [markdown]
# # HNSW Visualization with Federpy
#
# This notebook visualizes the HNSW graph structure using `federpy`. It downloads the necessary embedding data using `gdown` (as seen in other project files) and displays nodes with associated images.

# %%
# Install necessary packages, including gdown for data download
# !pip install federpy hnswlib h5py numpy pandas gdown
# Out:
# Requirement already satisfied: federpy in ./.venv/lib/python3.12/site-packages (0.8.0)
# Requirement already satisfied: hnswlib in ./.venv/lib/python3.12/site-packages (0.8.0)
# Requirement already satisfied: h5py in ./.venv/lib/python3.12/site-packages (3.15.1)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (2.3.3)
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Collecting beautifulsoup4 (from gdown)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from gdown) (3.20.0)
# Requirement already satisfied: requests[socks] in ./.venv/lib/python3.12/site-packages (from gdown) (2.32.5)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from gdown) (4.67.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->gdown)
#   Using cached soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./.venv/lib/python3.12/site-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests[socks]->gdown) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests[socks]->gdown) (2025.11.12)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached soupsieve-2.8-py3-none-any.whl (36 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Installing collected packages: soupsieve, PySocks, beautifulsoup4, gdown
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [gdown]32m3/4 [gdown]fulsoup4]
# Successfully installed PySocks-1.7.1 beautifulsoup4-4.14.3 gdown-5.2.0 soupsieve-2.8

# %%
import hnswlib
import numpy as np
import h5py
import os
import gdown
from federpy.federpy import FederPy
import random

# %% [markdown]
# ## 1. Load Data
# We download `Image_Embedded.h5` from Google Drive using the ID found in `hnsw_search/hnsw.ipynb` (`12R_DHBMOVFVEaPrjBEQXOd7tb14Isb1D`). This ensures we have a valid HDF5 file.

# %%
DATA_FILE = 'backend/temp/Image_Embedded.h5'
os.makedirs(os.path.dirname(DATA_FILE), exist_ok=True)

if not os.path.exists(DATA_FILE) or os.path.getsize(DATA_FILE) < 1000:
    print(f"Downloading {DATA_FILE}...")
    # ID found in hnsw_search/hnsw.ipynb for Image_Embedded.h5
    file_id = '12R_DHBMOVFVEaPrjBEQXOd7tb14Isb1D'
    url = f'https://drive.google.com/uc?id={file_id}'
    gdown.download(url, DATA_FILE, quiet=False)

NUM_ELEMENTS = 1000000  # Visualize a subset
DIM = 512           

embeddings = None
image_urls = None

print(f"Loading {DATA_FILE}...")
try:
    with h5py.File(DATA_FILE, 'r') as f:
        if 'embeddings' not in f or 'urls' not in f:
                raise ValueError("File missing 'embeddings' or 'urls' keys")
        
        # Check if we have enough data
        NUM_ELEMENTS = f['embeddings'].shape[0]
        # if total_items < NUM_ELEMENTS:
        #     print(f"Warning: Requested {NUM_ELEMENTS} elements but file only has {total_items}. Using all available.")
        #     NUM_ELEMENTS = total_items
        
        embeddings = f['embeddings'][:NUM_ELEMENTS]
        urls_raw = f['urls'][:NUM_ELEMENTS]
        
        image_urls = []
        for url in urls_raw:
            if isinstance(url, bytes):
                image_urls.append(url.decode('utf-8'))
            else:
                image_urls.append(str(url))
        
        DIM = embeddings.shape[1]
        print(f"Successfully loaded {len(embeddings)} items with dimension {DIM}.")

except OSError as e:
    raise OSError(f"Failed to open file {DATA_FILE}. It might be corrupted. Error: {e}")
# Out:
# Loading backend/temp/Image_Embedded.h5...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 25
#      23 # Check if we have enough data
#      24 NUM_ELEMENTS = f['embeddings'].shape[0]
# ---> 25 if total_items < NUM_ELEMENTS:
#      26     print(f"Warning: Requested {NUM_ELEMENTS} elements but file only has {total_items}. Using all available.")
#      27     NUM_ELEMENTS = total_items
#
# NameError: name 'total_items' is not defined

# %% [markdown]
# ## 2. Build HNSW Index

# %%
INDEX_FILE = 'temp_index.bin'

print("Building HNSW index...")
p = hnswlib.Index(space='l2', dim=DIM)
p.init_index(max_elements=NUM_ELEMENTS, ef_construction=200, M=16)
p.add_items(embeddings, np.arange(NUM_ELEMENTS))
p.set_ef(50)
p.save_index(INDEX_FILE)
print(f"Index saved to {INDEX_FILE}")
# Out:
# Building HNSW index...

# %% [markdown]
# ## 3. Visualize with FederPy

# %%
# Initialize FederPy with view parameters for images
view_params = {
    "width": 800,
    "height": 600,
    "mediaType": "image",
    "mediaUrls": image_urls
}

feder = FederPy(INDEX_FILE, 'hnswlib', **view_params)

print("Generating Overview...")
feder.overview()
# Out:
# Generating Overview...
# <!DOCTYPE html>
# <html>
#
# <head>
#   <meta charset="utf-8" />
#   <meta name="viewport" content="width=device-width,initial-scale=1" />
#   <meta name="theme-color" content="#ffffff" />
#   <title>Feder</title>
# </head>
#
# <body style="background: #000">
#   <div id="feder-container-5162369" />
# </body>
#
# <script type="module">
#
#
# import { Feder } from "https://unpkg.com/@zilliz/feder"
# // console.log(Feder)
#
# const mediaUrls = ['https://c1.staticflickr.com/1/67/197493648_628a7cb2ee_o.jpg','https://c6.staticflickr.com/4/3930/15342460029_6f441b0439_o.jpg','https://c7.staticflickr.com/1/668/21529344631_4bdf3c253a_o.jpg','https://farm3.staticflickr.com/3892/14587227141_d36fa37264_o.jpg','https://c5.staticflickr.com/5/4024/4323769914_8f7b8a4a55_o.jpg','https://c5.staticflickr.com/4/3871/14594283694_43c91ce7f9_o.jpg','https://c4.staticflickr.com/8/7335/12405729553_4d56279bcc_o.jpg','https://c3.staticflickr.com/1/95/222640893_86cf9e06d3_o.jpg','https://c1.staticflickr.com/8/7247/7031812547_9656fd4dc0_o.jpg','https://c1.staticflickr.com/8/7514/16027156246_9e02788624_o.jpg','https://farm2.staticflickr.com/7550/16100965099_cdbb7f94b7_o.jpg','https://c8.staticflickr.com/7/6167/6148156477_3e3fc45011_o.jpg','https://farm8.staticflickr.com/4024/4285022522_1482c778bd_o.jpg','https://farm2.staticflickr.com/3227/2467157966_a1849d692b_o.jpg','https://farm4.staticflickr.com/8729/16609399917_179449be23_o.jpg','https://farm7.staticflickr.com/3836/14914119879_70594d343e_o.jpg','https://farm4.staticflickr.com/108/301275695_b6c35bcc8d_o.jpg','https://farm7.staticflickr.com/3434/3387867256_889149b874_o.jpg','https://c2.staticflickr.com/3/2731/4174544191_a76fd8217c_o.jpg','https://c2.staticflickr.com/3/2867/13524336924_c592158a59_o.jpg','https://c1.staticflickr.com/9/8765/17683556749_3dbce8f673_o.jpg','https://c3.staticflickr.com/3/2943/15340150431_babca63042_o.jpg','https://farm3.staticflickr.com/7437/9737323118_050b0564ae_o.jpg','https://c4.staticflickr.com/7/6221/6271161652_b21a5c487e_o.jpg','https://farm4.staticflickr.com/2721/5796182797_7d4879f440_o.jpg','https://farm3.staticflickr.com/8837/18700600876_7187b8e8b4_o.jpg','https://c4.staticflickr.com/8/7290/10783232614_d48f4e6cec_o.jpg','https://c6.staticflickr.com/5/4044/5143636300_d74144e2f4_o.jpg','https://c4.staticflickr.com/7/6029/6021246355_4e90fa9b0b_o.jpg','https://farm5.staticflickr.com/3117/2508651938_1b2a89be4a_o.jpg','https://c6.staticflickr.com/9/8165/7681236564_46fbaf72df_o.jpg','https://farm7.staticflickr.com/1274/5184826115_7bd3b334c6_o.jpg','https://farm5.staticflickr.com/3790/12309075964_084010b7a8_o.jpg','https://farm8.staticflickr.com/8713/16363758634_bd61bc8177_o.jpg','https://farm7.staticflickr.com/3/6447081_de88a0705d_o.jpg','https://farm5.staticflickr.com/12/16458423_001c8b122c_o.jpg','https://c2.staticflickr.com/8/7147/6630031491_ffeeb5f913_o.jpg','https://c5.staticflickr.com/9/8182/8042853066_b705a95ae6_o.jpg','https://farm4.staticflickr.com/6091/6260619644_a631787c48_o.jpg','https://c3.staticflickr.com/8/7398/9115108144_b8b888f48e_o.jpg','https://farm4.staticflickr.com/187/481874094_2c043abbaf_o.jpg','https://c4.staticflickr.com/8/7450/12990465045_27e1635588_o.jpg','https://farm5.staticflickr.com/3806/9328438064_e4aa4ecf3d_o.jpg','https://farm4.staticflickr.com/7287/16900966276_b0841be02c_o.jpg','https://c5.staticflickr.com/7/6044/6303042574_3d0de842ba_o.jpg','https://farm3.staticflickr.com/4088/5175765831_f22a5b20fd_o.jpg','https://c2.staticflickr.com/8/7075/6859797304_cc5d23174c_o.jpg','https://farm3.staticflickr.com/6200/6147267502_2d3efd5ab8_o.jpg','https://farm8.staticflickr.com/8523/8630136435_07bc97f0a7_o.jpg','https://c4.staticflickr.com/6/5443/18231828633_f80b5d1fdf_o.jpg','https://c8.staticflickr.com/8/7629/16558371028_6c8b9427de_o.jpg','https://c4.staticflickr.com/4/3199/2887130819_1a83ac2b26_o.jpg','https://farm7.staticflickr.com/8610/15735020594_a09096a201_o.jpg','https://farm2.staticflickr.com/5613/15283317839_38dfe407dd_o.jpg','https://c5.staticflickr.com/4/3881/15161181415_40b4be608c_o.jpg','https://c4.staticflickr.com/4/3390/3474684694_ef877f5a10_o.jpg','https://farm3.staticflickr.com/3130/3247101661_ee8d35bc58_o.jpg','https://c3.staticflickr.com/6/5593/14960969116_765a9d7fea_o.jpg','https://c3.staticflickr.com/9/8167/7562846292_8fc4377fd6_o.jpg','https://c6.staticflickr.com/6/5777/20945997266_6e0fa51004_o.jpg','https://farm5.staticflickr.com/3420/3349556787_d7 ...

# %% [markdown]
# ## 4. Visualize Search

# %%
query_vector = np.random.rand(DIM).astype(np.float32)
k = 4

print("Visualizing Search...")
# feder.searchRandTestVec()
feder.searchByVec(query_vector)
# Out:
# Visualizing Search...
# <!DOCTYPE html>
# <html>
#
# <head>
#   <meta charset="utf-8" />
#   <meta name="viewport" content="width=device-width,initial-scale=1" />
#   <meta name="theme-color" content="#ffffff" />
#   <title>Feder</title>
# </head>
#
# <body style="background: #000">
#   <div id="feder-container-4593912" />
# </body>
#
# <script type="module">
#
#
# import { Feder } from "https://unpkg.com/@zilliz/feder"
# // console.log(Feder)
#
# const mediaUrls = ['https://c1.staticflickr.com/1/67/197493648_628a7cb2ee_o.jpg','https://c6.staticflickr.com/4/3930/15342460029_6f441b0439_o.jpg','https://c7.staticflickr.com/1/668/21529344631_4bdf3c253a_o.jpg','https://farm3.staticflickr.com/3892/14587227141_d36fa37264_o.jpg','https://c5.staticflickr.com/5/4024/4323769914_8f7b8a4a55_o.jpg','https://c5.staticflickr.com/4/3871/14594283694_43c91ce7f9_o.jpg','https://c4.staticflickr.com/8/7335/12405729553_4d56279bcc_o.jpg','https://c3.staticflickr.com/1/95/222640893_86cf9e06d3_o.jpg','https://c1.staticflickr.com/8/7247/7031812547_9656fd4dc0_o.jpg','https://c1.staticflickr.com/8/7514/16027156246_9e02788624_o.jpg','https://farm2.staticflickr.com/7550/16100965099_cdbb7f94b7_o.jpg','https://c8.staticflickr.com/7/6167/6148156477_3e3fc45011_o.jpg','https://farm8.staticflickr.com/4024/4285022522_1482c778bd_o.jpg','https://farm2.staticflickr.com/3227/2467157966_a1849d692b_o.jpg','https://farm4.staticflickr.com/8729/16609399917_179449be23_o.jpg','https://farm7.staticflickr.com/3836/14914119879_70594d343e_o.jpg','https://farm4.staticflickr.com/108/301275695_b6c35bcc8d_o.jpg','https://farm7.staticflickr.com/3434/3387867256_889149b874_o.jpg','https://c2.staticflickr.com/3/2731/4174544191_a76fd8217c_o.jpg','https://c2.staticflickr.com/3/2867/13524336924_c592158a59_o.jpg','https://c1.staticflickr.com/9/8765/17683556749_3dbce8f673_o.jpg','https://c3.staticflickr.com/3/2943/15340150431_babca63042_o.jpg','https://farm3.staticflickr.com/7437/9737323118_050b0564ae_o.jpg','https://c4.staticflickr.com/7/6221/6271161652_b21a5c487e_o.jpg','https://farm4.staticflickr.com/2721/5796182797_7d4879f440_o.jpg','https://farm3.staticflickr.com/8837/18700600876_7187b8e8b4_o.jpg','https://c4.staticflickr.com/8/7290/10783232614_d48f4e6cec_o.jpg','https://c6.staticflickr.com/5/4044/5143636300_d74144e2f4_o.jpg','https://c4.staticflickr.com/7/6029/6021246355_4e90fa9b0b_o.jpg','https://farm5.staticflickr.com/3117/2508651938_1b2a89be4a_o.jpg','https://c6.staticflickr.com/9/8165/7681236564_46fbaf72df_o.jpg','https://farm7.staticflickr.com/1274/5184826115_7bd3b334c6_o.jpg','https://farm5.staticflickr.com/3790/12309075964_084010b7a8_o.jpg','https://farm8.staticflickr.com/8713/16363758634_bd61bc8177_o.jpg','https://farm7.staticflickr.com/3/6447081_de88a0705d_o.jpg','https://farm5.staticflickr.com/12/16458423_001c8b122c_o.jpg','https://c2.staticflickr.com/8/7147/6630031491_ffeeb5f913_o.jpg','https://c5.staticflickr.com/9/8182/8042853066_b705a95ae6_o.jpg','https://farm4.staticflickr.com/6091/6260619644_a631787c48_o.jpg','https://c3.staticflickr.com/8/7398/9115108144_b8b888f48e_o.jpg','https://farm4.staticflickr.com/187/481874094_2c043abbaf_o.jpg','https://c4.staticflickr.com/8/7450/12990465045_27e1635588_o.jpg','https://farm5.staticflickr.com/3806/9328438064_e4aa4ecf3d_o.jpg','https://farm4.staticflickr.com/7287/16900966276_b0841be02c_o.jpg','https://c5.staticflickr.com/7/6044/6303042574_3d0de842ba_o.jpg','https://farm3.staticflickr.com/4088/5175765831_f22a5b20fd_o.jpg','https://c2.staticflickr.com/8/7075/6859797304_cc5d23174c_o.jpg','https://farm3.staticflickr.com/6200/6147267502_2d3efd5ab8_o.jpg','https://farm8.staticflickr.com/8523/8630136435_07bc97f0a7_o.jpg','https://c4.staticflickr.com/6/5443/18231828633_f80b5d1fdf_o.jpg','https://c8.staticflickr.com/8/7629/16558371028_6c8b9427de_o.jpg','https://c4.staticflickr.com/4/3199/2887130819_1a83ac2b26_o.jpg','https://farm7.staticflickr.com/8610/15735020594_a09096a201_o.jpg','https://farm2.staticflickr.com/5613/15283317839_38dfe407dd_o.jpg','https://c5.staticflickr.com/4/3881/15161181415_40b4be608c_o.jpg','https://c4.staticflickr.com/4/3390/3474684694_ef877f5a10_o.jpg','https://farm3.staticflickr.com/3130/3247101661_ee8d35bc58_o.jpg','https://c3.staticflickr.com/6/5593/14960969116_765a9d7fea_o.jpg','https://c3.staticflickr.com/9/8167/7562846292_8fc4377fd6_o.jpg','https://c6.staticflickr.com/6/5777/20945997266_6e0fa51004_o.jpg','https://farm5.staticflickr.com/3420/3349556787_d7 ...

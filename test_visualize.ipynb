# %%
from simple_hnsw.src.simple_hnsw.hnsw import HNSW
import numpy as np

index = HNSW('l2', 10)
index.init_index(50, M=3, ef_construction=6)

train_data = np.random.rand(40, 10)
query_data = np.random.rand(10)

index.insert_items(train_data)

# %%
index.visualize_search(train_data, k=5)
# Out:
# [25, 1, 4, 24, 21]

# %%
index.visualize_hierarchical_graph()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # 1. INSTALL & SETUP

# %%
# !pip install gdown hnswlib
# !git clone https://github.com/huynguyen6906/EmbedX.git
# !pip install -r EmbedX/requirements.txt
# !cd EmbedX && pip install .
# Out:
# Collecting gdown
#   Using cached gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting hnswlib
#   Using cached hnswlib-0.8.0.tar.gz (36 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from gdown) (4.14.2)
# Requirement already satisfied: filelock in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from gdown) (3.20.0)
# Requirement already satisfied: requests[socks] in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from gdown) (2.32.5)
# Requirement already satisfied: tqdm in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from gdown) (4.67.1)
# Requirement already satisfied: numpy in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from hnswlib) (2.3.4)
# Requirement already satisfied: soupsieve>1.2 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from requests[socks]->gdown) (2025.10.5)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Building wheels for collected packages: hnswlib
#   Building wheel for hnswlib (pyproject.toml) ... done
#   Created wheel for hnswlib: filename=hnswlib-0.8.0-cp312-cp312-linux_x86_64.whl size=225275 sha256=3242f6bc2045291f16c66fded1e195b215529e48284a74c8aa0c39f8dbba5665
#   Stored in directory: /home/huynguyen/.cache/pip/wheels/ac/39/b3/cbd7f9cbb76501d2d5fbc84956e70d0b94e788aac87bda465e
# Successfully built hnswlib
# Installing collected packages: PySocks, hnswlib, gdown
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [gdown]
# Successfully installed PySocks-1.7.1 gdown-5.2.0 hnswlib-0.8.0
# fatal: destination path 'EmbedX' already exists and is not an empty directory.
# Requirement already satisfied: torch in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from -r EmbedX/requirements.txt (line 1)) (2.9.0)
# Requirement already satisfied: numpy in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from -r EmbedX/requirements.txt (line 2)) (2.3.4)
# Requirement already satisfied: h5py in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from -r EmbedX/requirements.txt (line 3)) (3.15.1)
# Requirement already satisfied: tqdm in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from -r EmbedX/requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: PyMuPDF in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from -r EmbedX/requirements.txt (line 5)) (1.26.5)
# Requirement already satisfied: sentence-transformers in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from -r EmbedX/requirements.txt (line 6)) (5.1.2)
# Requirement already satisfied: Pillow in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from -r EmbedX/requirements.txt (line 7)) (12.0.0)
# Requirement already satisfied: ftfy in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from -r EmbedX/requirements.txt (line 8)) (6.3.1)
# Requirement already satisfied: regex in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from -r EmbedX/requirements.txt (line 9)) (2025.10.23)
# Requirement already satisfied: clip-anytorch in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from -r EmbedX/requirements.txt (line 10)) (2.6.0)
# Requirement already satisfied: python-docx in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from -r EmbedX/requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: bs4 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from -r EmbedX/requirements.txt (line 12)) (0.0.2)
# Requirement already satisfied: scikit-learn in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from -r EmbedX/requirements.txt (line 13)) (1.7.2)
# Requirement already satisfied: filelock in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (3.5)
# Requirement already satisfied: jinja2 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->-r EmbedX/requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from sentence-transformers->-r EmbedX/requirements.txt (line 6)) (4.57.1)
# Requirement already satisfied: scipy in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from sentence-transformers->-r EmbedX/requirements.txt (line 6)) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from sentence-transformers->-r EmbedX/requirements.txt (line 6)) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r EmbedX/requirements.txt (line 6)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r EmbedX/requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: requests in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r EmbedX/requirements.txt (line 6)) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r EmbedX/requirements.txt (line 6)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r EmbedX/requirements.txt (line 6)) (0.6.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers->-r EmbedX/requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: wcwidth in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from ftfy->-r EmbedX/requirements.txt (line 8)) (0.2.14)
# Requirement already satisfied: torchvision in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from clip-anytorch->-r EmbedX/requirements.txt (line 10)) (0.24.0)
# Requirement already satisfied: lxml>=3.1.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from python-docx->-r EmbedX/requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: beautifulsoup4 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from bs4->-r EmbedX/requirements.txt (line 12)) (4.14.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from scikit-learn->-r EmbedX/requirements.txt (line 13)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from scikit-learn->-r EmbedX/requirements.txt (line 13)) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from sympy>=1.13.3->torch->-r EmbedX/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from beautifulsoup4->bs4->-r EmbedX/requirements.txt (line 12)) (2.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from jinja2->torch->-r EmbedX/requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers->-r EmbedX/requirements.txt (line 6)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers->-r EmbedX/requirements.txt (line 6)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers->-r EmbedX/requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers->-r EmbedX/requirements.txt (line 6)) (2025.10.5)
# Processing /mnt/F248F21748F1DA75/DSA/hnsw/hnsw_search/EmbedX
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from embedx==0.1.0) (2.9.0)
# Requirement already satisfied: numpy in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from embedx==0.1.0) (2.3.4)
# Requirement already satisfied: h5py in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from embedx==0.1.0) (3.15.1)
# Requirement already satisfied: tqdm in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from embedx==0.1.0) (4.67.1)
# Requirement already satisfied: PyMuPDF in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from embedx==0.1.0) (1.26.5)
# Requirement already satisfied: sentence-transformers in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from embedx==0.1.0) (5.1.2)
# Requirement already satisfied: Pillow in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from embedx==0.1.0) (12.0.0)
# Requirement already satisfied: ftfy in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from embedx==0.1.0) (6.3.1)
# Requirement already satisfied: regex in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from embedx==0.1.0) (2025.10.23)
# Requirement already satisfied: clip-anytorch in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from embedx==0.1.0) (2.6.0)
# Requirement already satisfied: python-docx in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from embedx==0.1.0) (1.2.0)
# Requirement already satisfied: bs4 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from embedx==0.1.0) (0.0.2)
# Requirement already satisfied: scikit-learn in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from embedx==0.1.0) (1.7.2)
# Requirement already satisfied: beautifulsoup4 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from bs4->embedx==0.1.0) (4.14.2)
# Requirement already satisfied: soupsieve>1.2 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from beautifulsoup4->bs4->embedx==0.1.0) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from beautifulsoup4->bs4->embedx==0.1.0) (4.15.0)
# Requirement already satisfied: torchvision in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from clip-anytorch->embedx==0.1.0) (0.24.0)
# Requirement already satisfied: wcwidth in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from ftfy->embedx==0.1.0) (0.2.14)
# Requirement already satisfied: lxml>=3.1.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from python-docx->embedx==0.1.0) (6.0.2)
# Requirement already satisfied: scipy>=1.8.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from scikit-learn->embedx==0.1.0) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from scikit-learn->embedx==0.1.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from scikit-learn->embedx==0.1.0) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from sentence-transformers->embedx==0.1.0) (4.57.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from sentence-transformers->embedx==0.1.0) (0.36.0)
# Requirement already satisfied: filelock in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->embedx==0.1.0) (3.20.0)
# Requirement already satisfied: packaging>=20.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->embedx==0.1.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->embedx==0.1.0) (6.0.3)
# Requirement already satisfied: requests in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->embedx==0.1.0) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->embedx==0.1.0) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->embedx==0.1.0) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers->embedx==0.1.0) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers->embedx==0.1.0) (1.2.0)
# Requirement already satisfied: setuptools in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (3.5)
# Requirement already satisfied: jinja2 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from torch->embedx==0.1.0) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from sympy>=1.13.3->torch->embedx==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from jinja2->torch->embedx==0.1.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers->embedx==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers->embedx==0.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers->embedx==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers->embedx==0.1.0) (2025.10.5)
# Building wheels for collected packages: embedx
#   DEPRECATION: Building 'embedx' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'embedx'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for embedx (setup.py) ... done
#   Created wheel for embedx: filename=embedx-0.1.0-py3-none-any.whl size=5328 sha256=3215c66436b3466890e90dbdd5f69745ff91857f3bd844d4c1e54f752bacfe38
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m2stwv3d/wheels/75/5c/66/b0debb90339eca7af7bcb620053c3bdb69b982d488799f7ab8
# Successfully built embedx
# Installing collected packages: embedx
#   Attempting uninstall: embedx
#     Found existing installation: embedx 0.1.0
#     Uninstalling embedx-0.1.0:
#       Successfully uninstalled embedx-0.1.0
# Successfully installed embedx-0.1.0

# %%
import hnswlib
import gdown
import h5py
import clip
import embedx
import json
import torch
from sentence_transformers import SentenceTransformer
import os
import numpy as np
# Out:
# /home/huynguyen/miniconda3/envs/workspace/lib/python3.12/site-packages/clip/clip.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import packaging

# %% [markdown]
# # 2. DOWNLOAD CACHE

# %%
# Ensure the local directory for caching files exists.
os.makedirs(".cache", exist_ok=True)

if not os.path.isfile(".cache/Papers_Embedbed_0-1000000.h5"):
    # If not present, download the snapshot file using its Google Drive ID.
    gdown.download(id='1hMNur1U24ULce6osanfrePuCAz5uIvc3', output='.cache/Papers_Embedbed_0-1000000.h5', quiet=False)

if not os.path.isfile(".cache/hnsw_paper_index.bin"):
    # If not present, download the snapshot file using its Google Drive ID.
    gdown.download(id='1RR1o_eX9LKv_3pd9Iz1y4xB90pQIpUuX', output='.cache/hnsw_paper_index.bin', quiet=False)

if not os.path.isfile(".cache/hnsw_paper_index.json"):
    # If not present, download the snapshot file using its Google Drive ID.
    gdown.download(id='1H_BNLy9fXYwaOCXvZBRawN8S0w_KuGIK', output='.cache/hnsw_paper_index.json', quiet=False)

if not os.path.isfile(".cache/Image_Embedded.h5"):
    # If not present, download the snapshot file using its Google Drive ID.
    gdown.download(id='12R_DHBMOVFVEaPrjBEQXOd7tb14Isb1D', output='.cache/Image_Embedded.h5', quiet=False)

if not os.path.isfile(".cache/hnsw_image_index.bin"):
    # If not present, download the snapshot file using its Google Drive ID.
    gdown.download(id='1vWbJFLTdFnT6N2cnpMDA7c85JCfrY-QH', output='.cache/hnsw_image_index.bin', quiet=False)

if not os.path.isfile(".cache/hnsw_image_index.json"):
    # If not present, download the snapshot file using its Google Drive ID.
    gdown.download(id='16F8VRuKZb4SJ0KLa1Oh281RvdmQzj6Ft', output='.cache/hnsw_image_index.json', quiet=False)

# %% [markdown]
# # 3. SEARCH IMAGE BY HNSW

# %%
with h5py.File(".cache/Image_Embedded.h5", "r") as f:
  image_urls = f["urls"][:]
  image_embeddings = f["embeddings"][:]

# %%
image_index_config = ".cache/hnsw_image_index.json"
dim_image = 0
max_element_image = 0
ef_image = 0
with open(image_index_config, 'r') as f:
    data = json.load(f)
    dim_image = data[0]
    max_element_image = data[1]
    ef_image = data[2]

# %%
image_index_file = ".cache/hnsw_image_index.bin"

if os.path.exists(image_index_file):
    image_search = hnswlib.Index(space='cosine', dim=dim_image)
    image_search.load_index(image_index_file, max_elements=max_element_image) 
    image_search.set_ef(ef_image)   
else:
    print("❌ ERROR: file is not exist.")

# %%
Text_queries = ["computer", "chemical", "single"]
queries = [embedx.image.embed_Text(Text_queries[i]) for i in range(len(Text_queries))]
indices, distances = image_search.knn_query(queries, k=10)
for i in range(len(Text_queries)):
  print(Text_queries[i])
  for idx in indices[i]:
    print(image_urls[idx])
del indices
del distances
# Out:
# computer
# b'https://farm4.staticflickr.com/4145/5144385210_11af7a12b3_o.jpg'
# b'https://c1.staticflickr.com/8/7066/6986311580_f25426e4c8_o.jpg'
# b'https://c4.staticflickr.com/1/115/309069511_061d065296_o.jpg'
# b'https://c5.staticflickr.com/2/1055/1040841974_7ec01b4d9f_o.jpg'
# b'https://farm6.staticflickr.com/2803/5713954047_4cd45a029d_o.jpg'
# b'https://farm7.staticflickr.com/2746/4267363398_b770c0757e_o.jpg'
# b'https://c3.staticflickr.com/2/1056/986204626_8d7252a06a_o.jpg'
# b'https://farm7.staticflickr.com/206/487304481_a7c6b071cc_o.jpg'
# b'https://c1.staticflickr.com/3/2364/1798975528_b15ffc491d_o.jpg'
# b'https://farm8.staticflickr.com/4006/4673592688_4f8abde8a7_o.jpg'
# chemical
# b'https://farm3.staticflickr.com/3795/10044488764_132b77a668_o.jpg'
# b'https://c1.staticflickr.com/8/7019/6523859709_3904afb388_o.jpg'
# b'https://c7.staticflickr.com/4/3665/9914382424_f77338be49_o.jpg'
# b'https://farm1.staticflickr.com/19/99996654_dd3692c886_o.jpg'
# b'https://c5.staticflickr.com/7/6208/6136234094_13d9df22f5_o.jpg'
# b'https://farm4.staticflickr.com/5012/5516556783_d657d65c29_o.jpg'
# b'https://c5.staticflickr.com/5/4151/5015111369_e5361d3f8f_o.jpg'
# b'https://c8.staticflickr.com/4/3192/2532924598_0c6ccb35d0_o.jpg'
# b'https://c4.staticflickr.com/6/5243/5313112849_6dae4ce858_o.jpg'
# b'https://farm5.staticflickr.com/7357/12568984634_5733303ecd_o.jpg'
# single
# b'https://c5.staticflickr.com/6/5034/5875733647_d14312dc43_o.jpg'
# b'https://c3.staticflickr.com/8/7486/15858102906_da3dcb7c96_o.jpg'
# b'https://c5.staticflickr.com/8/7493/15698299967_819b252bab_o.jpg'
# b'https://c6.staticflickr.com/9/8649/16056159470_c7a1232c9a_o.jpg'
# b'https://c2.staticflickr.com/6/5311/5886864144_73c556e03e_o.jpg'
# b'https://farm2.staticflickr.com/8033/7959989644_f50bf593e8_o.jpg'
# b'https://farm8.staticflickr.com/8097/8488722362_d92a0bae30_o.jpg'
# b'https://c3.staticflickr.com/9/8210/8173524342_57f5c44818_o.jpg'
# b'https://farm6.staticflickr.com/5174/5482949534_efaa3c2b96_o.jpg'
# b'https://farm7.staticflickr.com/8152/7314522138_e1d842b50d_o.jpg'

# %%
del image_urls
del image_embeddings
del image_index_config
del image_search
del image_index_file
del dim_image
del max_element_image
del ef_image

# %% [markdown]
# # 4. SEARCH PAPER BY HNSW

# %%
with h5py.File(".cache/Papers_Embedbed_0-1000000.h5", "r") as f:
  paper_urls = f["urls"][:]
  paper_embeddings = f["embeddings"][:]

# %%
paper_index_config = ".cache/hnsw_paper_index.json"
dim_paper = 0
max_element_paper = 0
ef_paper = 0
with open(paper_index_config, 'r') as f:
    data = json.load(f)
    dim_paper = data[0]
    max_element_paper = data[1]
    ef_paper = data[2]

# %%
paper_index_file = ".cache/hnsw_paper_index.bin"

if os.path.exists(paper_index_file):
    paper_search = hnswlib.Index(space='cosine', dim=dim_paper)
    paper_search.load_index(paper_index_file, max_elements=max_element_paper) 
    paper_search.set_ef(ef_paper)   
else:
    print("❌ ERROR: file is not exist.")

# %%
Text_queries = ["computer", "chemical"]
queries = [embedx.text.embed_Text(Text_queries[i]) for i in range(len(Text_queries))]
indices, distances = paper_search.knn_query(queries, k=10)
for i in range(len(Text_queries)):
  print(Text_queries[i])
  for idx in indices[i]:
    print(paper_urls[idx])
del indices
del distances
# Out:
# computer
# b'https://arxiv.org/pdf/1309.5737.pdf'
# b'https://arxiv.org/pdf/1107.3893.pdf'
# b'https://arxiv.org/pdf/1107.4217.pdf'
# b'https://arxiv.org/pdf/0903.4286.pdf'
# b'https://arxiv.org/pdf/1304.1428.pdf'
# b'https://arxiv.org/pdf/1712.09404.pd'
# b'https://arxiv.org/pdf/1312.2447.pdf'
# b'https://arxiv.org/pdf/1703.02944.pd'
# b'https://arxiv.org/pdf/1202.5944.pdf'
# b'https://arxiv.org/pdf/0910.3440.pdf'
# chemical
# b'https://arxiv.org/pdf/1606.04381.pd'
# b'https://arxiv.org/pdf/1207.3242.pdf'
# b'https://arxiv.org/pdf/1307.6360.pdf'
# b'https://arxiv.org/pdf/1007.0818.pdf'
# b'https://arxiv.org/pdf/0708.1826.pdf'
# b'https://arxiv.org/pdf/1301.0833.pdf'
# b'https://arxiv.org/pdf/0906.0871.pdf'
# b'https://arxiv.org/pdf/1211.3163.pdf'
# b'https://arxiv.org/pdf/1601.05356.pd'
# b'https://arxiv.org/pdf/0901.0318.pdf'

# %%
del paper_urls
del paper_embeddings
del paper_index_config
del paper_search
del paper_index_file
del dim_paper
del max_element_paper
del ef_paper
